# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# #Install tfjs-converter using npm with a specific version
# !npm install -g @tensorflow/tfjs-converter@1.16.0


# !npm install @tensorflow/tfjs-core@4.16.0

# %%
#!pip uninstall tensorflowjs -y

# %%
# # Install Node.js (required for yarn)
# !apt-get install -y nodejs

# # Install yarn
# !npm install -g yarn

#  # Install tfjs-converter using yarn
# !yarn add @tensorflow/tfjs-converter@latest

# %%
# !npx tensorflowjs_converter --input_format=tf_saved_model --output_node_names='detection_boxes,detection_classes,detection_features,detection_multiclass_scores,detection_scores,num_detections,raw_detection_boxes,raw_detection_scores' --output_format=tfjs_graph_model /content/drive/MyDrive/saved_model /content/drive/MyDrive/modelstfjsgraph02
# Out:
# 2024-01-14 13:03:48.161764: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-14 13:03:48.161814: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-14 13:03:48.163225: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-14 13:03:48.170732: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
