# %%
import os
import tensorflow as tf

model = tf.keras.applications.mobilenet_v2.MobileNetV2(
    input_shape=(224, 224, 3), weights='imagenet',
    classifier_activation='softmax'
)
# Out:
# ...
# 14536120/14536120 [==============================] - 0s 0us/step

# %%
from google.colab import drive

# %%
# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# from tensorflow.python.saved_model.save import save

# save_dir = os.path.join('/tmp/', 'mobilenetv2/your_model.h5')
# model.save(save_dir)

# Path to the H5 file on Google Drive
h5_file_path = '/content/drive/MyDrive/model.h5'

# %%
# Copy the H5 file to Colab environment
copy_path = '/tmp/model.h5'
# !cp "{h5_file_path}" "{copy_path}"

# %%
# Load the model from the H5 file
model = tf.keras.models.load_model(copy_path)

# %%
# !pip install tensorflowjs
# Out:
# WARNING: Ignoring invalid distribution -eras (/usr/local/lib/python3.10/dist-packages)
# ...
#   Using cached tensorflowjs-4.13.0-py3-none-any.whl (89 kB)
# ...
#   Using cached tensorflow_decision_forests-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.3 MB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 440.7/440.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 54.8 MB/s eta 0:00:00
# ...
#   Using cached tensorflow-2.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (475.2 MB)
# ...
#   Using cached tensorboard-2.15.1-py3-none-any.whl (5.5 MB)
# ...
# WARNING: Ignoring invalid distribution -eras (/usr/local/lib/python3.10/dist-packages)
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.14.1
#     Uninstalling tensorboard-2.14.1:
#       Successfully uninstalled tensorboard-2.14.1
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.14.0
# ...

# %%
# !cd /tmp/mobilenetv2/
# !tensorflowjs_converter --input_format=keras --output_format=tfjs_layers_model /tmp/mobilenetv2/your_model.h5 /tmp/mobilenetv2/

# Convert the model to TensorFlow.js format
save_dir = '/tmp/mobilenetv2_tfjs'
# !tensorflowjs_converter --input_format=keras --output_format=tfjs_layers_model "{copy_path}" "{save_dir}"
# Out:
# 2023-11-28 14:14:54.171785: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-28 14:14:54.171835: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-28 14:14:54.173069: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-11-28 14:14:55.196979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Create a zip file
zip_file_path = '/tmp/mobilenetv2_tfjs.zip'
# !zip -r "/tmp/mobilenetv2_tfjs.zip" "/tmp/mobilenetv2_tfjs"
# Out:
#   adding: tmp/mobilenetv2_tfjs/ (stored 0%)
#   adding: tmp/mobilenetv2_tfjs/group1-shard1of1.bin (deflated 42%)
#   adding: tmp/mobilenetv2_tfjs/model.json (deflated 70%)

# %%
# Download the zip file
from google.colab import files
files.download(zip_file_path)
