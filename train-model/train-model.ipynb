# %%
# import required library
import tensorflow as tf
import numpy as np
import pandas as pd

# %%
# Read CSV file as a dataframe with pandas
data = pd.read_csv('/content/drive/MyDrive/train_labels.csv', header=None)

# %%
# Get statistical information
data.describe()
# Out:
#                           0    1    2      3    4    5    6     7
# count                   274  274  274    274  274  274  274   274
# unique                  204   92   82      4  232  233  239   240
# top     20230711_200717.jpg  460  690  penis  148  239  269  1127
# freq                      5  101   54    163    3    3    4     4

# %%
# print top records from dataframe
data.head()
# Out:
#                        0      1       2       3     4     5     6     7
# 0               filename  width  height   class  xmin  ymin  xmax  ymax
# 1  10232308_015_5205.jpg    159     183  vagina    48    31   114   175
# 2  11458736_011_9968.jpg    172     279  vagina    54    33   128   246
# 3  11467216_007_3eb2.jpg    226     141  breast     4    30   216   130
# 4  11511711_007_f8ce.jpg    168     297  vagina    38    18   145   220

# %%
import numpy as np

# Assuming data is a NumPy array with mixed data types including strings
data = np.array(['1.23', '2.34', 'filename', '4.56'])

# # Convert to float32, replace non-convertible values with NaN
# data = np.asarray(data, dtype='float32')

# %%
# Check modified data
data.head()
# Out:
#                        0      1       2       3     4     5     6     7
# 0               filename  width  height   class  xmin  ymin  xmax  ymax
# 1  10232308_015_5205.jpg    159     183  vagina    48    31   114   175
# 2  11458736_011_9968.jpg    172     279  vagina    54    33   128   246
# 3  11467216_007_3eb2.jpg    226     141  breast     4    30   216   130
# 4  11511711_007_f8ce.jpg    168     297  vagina    38    18   145   220

# %%
# Convert dataframe to numpy arrary
data=data.to_numpy()

# %%
# print shape of numpy arrary
data.shape
# Out:
# (274, 8)

# %%
# Get trainging and testing dataset from numpy
training = data [0:200]
testing = data[200:]

# %%
# print training and testing dataset shape
print(training.shape)
print(testing.shape)
# Out:
# (200, 8)
# (74, 8)

# %%
# separating true labels from training and testing datasets
training_features  = training[:,0:-1]
training_labels = training[:,-1]
testing_features = testing[:,0:-1]
testing_labels = testing[:,-1]

# %%
# print shape of input that training_features and true labels that is training_labels
print(training_features.shape)
print(training_labels.shape)
# Out:
# (200, 7)
# (200,)

# %%
# checking input shape to neural network
training_features[0].shape
# Out:
# (7,)

# %%
# !pip install tensorflow

# %%
# import classes
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout

# %%
# from keras.models import Sequential
# from keras.layers import Conv2D, MaxPooling2D
# from keras.layers import Activation, Dropout, Dense
# np.random.seed(42)

# epochs = 10

# model = train()
# model.compile(optimizer='adam',
#               loss='binary_crossentropy',
#               metrics=['accuracy'])

# history = model.fit(X_train, y_train,
#                     validation_data=(X_test,y_test),
#                     batch_size=batch_size,
#                     epochs=epochs)

# %%
# Model definition
model = Sequential()
model.add(Input(shape=(7,)))
model.add(Dense(units=64,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=7,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='sigmoid'))

# %%
# # Configure model training
model = Sequential()
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# # Train Model
model.fit(training_features,training_labels,epochs=100,validation_data=(testing_features,testing_labels))
# Out:
# Epoch 1/100
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-511b3bbf0a6e> in <cell line: 2>()
#       1 # # Train Model
# ----> 2 model.fit(training_features,training_labels,epochs=100,validation_data=(testing_features,testing_labels))
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ...
